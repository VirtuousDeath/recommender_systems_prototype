# %%
data_ana = {    
	"user": {"name": "Ana"},
	"products": [
		{"name": "Cartão de Crédito", "value": 1},
		{"name": "Conta Corrente", "value": 2},
		{"name": "Poupança", "value": 3},
		{"name": "Renda Fixa", "value": 4},
		{"name": "Crédito Pessoal", "value": 5}
	]
}

data_marcos = {    
	"user": {"name": "Marcos"},
	"products": [
		{"name": "Cartão de Crédito", "value":  2},
		{"name": "Conta Corrente", "value":  3},
		{"name": "Poupança", "value":  4},
		{"name": "Renda Fixa", "value":  5},
		{"name": "Renda Variável", "value":  0.6}
	]
}

data_pedro = {    
	"user": {"name": "Pedro"},
	"products": [
		{"name": "Cartão de Crédito", "value":  3},
		{"name": "Conta Corrente", "value":  4},
		{"name": "Poupança", "value":  5},
		{"name": "Crédito Pessoal", "value":  7}
	]
}

data_claudia = {    
	"user": {"name": "Claudia"},
	"products": [
		{"name": "Cartão de Crédito", "value":  4},
		{"name": "Conta Corrente", "value":  5},
		{"name": "Poupança", "value":  6}
	]
}

# %%
product_1 = {"name": "Cartão de Crédito","likes": 1}
product_2 = {"name": "Conta Corrente","likes": 3}
product_3 = {"name": "Crédito Pessoal","likes": 2}
product_4 = {"name": "Poupança","likes": 0}
product_5 = {"name": "Renda Fixa","likes": 0}
product_6 = {"name": "Renda Variável","likes": 0}
# ou com todos
products = {
    "products": [
        {"name": "Cartão de Crédito","likes": 1},
        {"name": "Conta Corrente","likes": 3},
        {"name": "Crédito Pessoal","likes": 2},
        {"name": "Poupança","likes": 0},
        {"name": "Renda Fixa","likes": 0},
        {"name": "Renda Variável","likes": 0}
    ]
}
